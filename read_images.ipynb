# %%
import os
import numpy as np
import nibabel as nib
import matplotlib.pyplot as plt
import json
img = nib.load(os.path.join('/home/reyhan/ms_project/data/iDB-CERMEP/sub-0001/ct','sub-0001_ct.nii.gz'))
data = img.get_fdata()

# %%
plt.imshow(data[100,:,:], cmap='gray', origin='lower')
plt.xlabel('First axis')
plt.ylabel('Second axis')
plt.colorbar(label='Signal intensity')
plt.show()

# %%
# Opening JSON file
f = open(os.path.join('/home/reyhan/ms_project/data/iDB-CERMEP/sub-0001/ct','sub-0001_ct.json'))

# returns JSON object as
# a dictionary
# data = json.load(f)
f
# Out:
# <_io.TextIOWrapper name='/home/reyhan/ms_project/data/iDB-CERMEP/sub-0001/ct/sub-0001_ct.json' mode='r' encoding='UTF-8'>

# %%
import os
path_to_image_directory = '/home/reyhan/ms_project/data/70BrainSeg/70BrainSeg/2016-05-20_173335/2016-05-20_173335/20Repeats_2015-12-07_164118'
a = [os.path.join(path_to_image_directory, image_address) for image_address in os.listdir(path_to_image_directory) if image_address.split('.')[-1] == 'tgz']
# Out:
# ['/home/reyhan/ms_project/data/70BrainSeg/70BrainSeg/2016-05-20_173335/2016-05-20_173335/20Repeats_2015-12-07_164118/OAS1_0191_MR2.tgz',
#  '/home/reyhan/ms_project/data/70BrainSeg/70BrainSeg/2016-05-20_173335/2016-05-20_173335/20Repeats_2015-12-07_164118/OAS1_0379_MR2.tgz',
#  '/home/reyhan/ms_project/data/70BrainSeg/70BrainSeg/2016-05-20_173335/2016-05-20_173335/20Repeats_2015-12-07_164118/OAS1_0145_MR2.tgz',
#  '/home/reyhan/ms_project/data/70BrainSeg/70BrainSeg/2016-05-20_173335/2016-05-20_173335/20Repeats_2015-12-07_164118/OAS1_0156_MR2.tgz',
#  '/home/reyhan/ms_project/data/70BrainSeg/70BrainSeg/2016-05-20_173335/2016-05-20_173335/20Repeats_2015-12-07_164118/OAS1_0202_MR2.tgz',
#  '/home/reyhan/ms_project/data/70BrainSeg/70BrainSeg/2016-05-20_173335/2016-05-20_173335/20Repeats_2015-12-07_164118/OAS1_0239_MR2.tgz',
#  '/home/reyhan/ms_project/data/70BrainSeg/70BrainSeg/2016-05-20_173335/2016-05-20_173335/20Repeats_2015-12-07_164118/OAS1_0368_MR2.tgz',
# ...

# %%
from tarfile import TarFile

# open file
file = TarFile.extractall('/home/reyhan/ms_project/data/70BrainSeg/70BrainSeg/2016-05-20_173335/2016-05-20_173335/20Repeats_2015-12-07_164118/OAS1_0150_MR1.tgz')

# extracting file
# file.extractall('./OASISLabels')

file
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Input In [20], in <cell line: 4>()
#       1 from tarfile import TarFile
#       3 # open file
# ----> 4 file = TarFile.extractall('/home/reyhan/ms_project/data/70BrainSeg/70BrainSeg/2016-05-20_173335/2016-05-20_173335/20Repeats_2015-12-07_164118/OAS1_0150_MR1.tgz')
#       6 # extracting file
#       7 # file.extractall('./OASISLabels')
#       9 file
#
# File /usr/lib/python3.10/tarfile.py:2043, in TarFile.extractall(self, path, members, numeric_owner)
#    2040     members = self
#    2042 for tarinfo in members:
# -> 2043     if tarinfo.isdir():
#    2044         # Extract directories with a safe mode.
#    2045         directories.append(tarinfo)
#    2046         tarinfo = copy.copy(tarinfo)
#
# AttributeError: 'str' object has no attribute 'isdir'

# %%
import tarfile
tar = tarfile.open('/home/reyhan/ms_project/data/70BrainSeg/70BrainSeg/2016-05-20_173335/2016-05-20_173335/20Repeats_2015-12-07_164118/OAS1_0150_MR1.tgz')
tar.extractall()
tar

# %%
import os, sys, tarfile

my_tar = tarfile.open('/home/reyhan/ms_project/data/70BrainSeg/70BrainSeg/2016-05-20_173335/2016-05-20_173335/20Repeats_2015-12-07_164118/OAS1_0150_MR1.tgz')

my_tar

# %%
os.listdir(path_to_image_directory)
path_to_images_per_modality =  [os.path.join(path_to_image_directory, image_address) for image_address in os.listdir(path_to_image_directory) if image_address.split('.')[-1] == 'tgz']
